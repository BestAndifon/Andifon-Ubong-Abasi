# %% [markdown]
# ### importation of python libaries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### loading of dataset and Cleaning of dataset

# %%
df = pd.read_csv('amazon_2024_valentines_best_sellers.csv')
df
# Out:
#                                                  title           brand  \
# 0    Ferrero Rocher, 24 Count, Premium Milk Chocola...  Ferrero Rocher
# 1    HERSHEY'S NUGGETS Assorted Chocolate, Valentin...       HERSHEY'S
# 2    LEGO Icons Flower Bouquet Building Decoration ...            LEGO
# 3    BodyRefresh Shower Steamers Aromatherapy - 8 P...     BodyRefresh
# 4    JoJowell Shower Steamers Aromatherapy - 21Pcs ...        JoJowell
# ..                                                 ...             ...
# 213  JOYIN 28 Packs Valentine's Day Gift Cards with...           JOYIN
# 214  THEMEROL Natural Gemstone Bracelet Gifts for D...        THEMEROL
# 215  Juegoal 28 Pack Valentines Day Gift Cards for ...         Juegoal
# 216  Double Couple Gift for Mom Women-Rose Cute Bea...   Double Couple
# 217  Valentine's Day Gifts For Her - Rose in Glass ...       Norcalway
#
#                                            description  starsBreakdown/3star  \
# ...

# %% [markdown]
# ### reading the first five column and rows of dataset

# %%
df.head()
# Out:
#                                                title           brand  \
# 0  Ferrero Rocher, 24 Count, Premium Milk Chocola...  Ferrero Rocher
# 1  HERSHEY'S NUGGETS Assorted Chocolate, Valentin...       HERSHEY'S
# 2  LEGO Icons Flower Bouquet Building Decoration ...            LEGO
# 3  BodyRefresh Shower Steamers Aromatherapy - 8 P...     BodyRefresh
# 4  JoJowell Shower Steamers Aromatherapy - 21Pcs ...        JoJowell
#
#                                          description  starsBreakdown/3star  \
# 0  Ferrero Rocher's milk chocolate gift box offer...                  0.02
# 1  This HERSHEY'S NUGGETS candy assortment is fil...                  0.03
# 2  Giving and receiving beautiful flowers is such...                  0.01
# 3                                                NaN                  0.07
# 4                                                NaN                  0.10
#
#    starsBreakdown/4star  starsBreakdown/5star  reviewsCount  price  \
# ...

# %% [markdown]
# ### viewing the last five column and rows of the dataset

# %%
df.tail()
# Out:
#                                                  title          brand  \
# 213  JOYIN 28 Packs Valentine's Day Gift Cards with...          JOYIN
# 214  THEMEROL Natural Gemstone Bracelet Gifts for D...       THEMEROL
# 215  Juegoal 28 Pack Valentines Day Gift Cards for ...        Juegoal
# 216  Double Couple Gift for Mom Women-Rose Cute Bea...  Double Couple
# 217  Valentine's Day Gifts For Her - Rose in Glass ...      Norcalway
#
#     description  starsBreakdown/3star  starsBreakdown/4star  \
# 213         NaN                  0.14                  0.17
# 214         NaN                  0.03                  0.07
# 215         NaN                  0.05                  0.16
# 216         NaN                  0.06                  0.15
# 217         NaN                  0.04                  0.10
#
#      starsBreakdown/5star  reviewsCount  price price/currency  price/value  \
# 213                  0.55          30.0    NaN              $        22.99
# ...

# %% [markdown]
# ### veiwing the summary of essential information of dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 218 entries, 0 to 217
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   title                             218 non-null    object
#  1   brand                             217 non-null    object
#  2   description                       46 non-null     object
#  3   starsBreakdown/3star              218 non-null    float64
#  4   starsBreakdown/4star              218 non-null    float64
#  5   starsBreakdown/5star              218 non-null    float64
#  6   reviewsCount                      216 non-null    float64
#  7   price                             0 non-null      float64
#  8   price/currency                    169 non-null    object
#  9   price/value                       169 non-null    float64
#  10  categoryPageData/productPosition  218 non-null    int64
# dtypes: float64(6), int64(1), object(4)
# ...

# %% [markdown]
# ### creating a separate independent copy of dataframe to prevent any unintended effects

# %%
df.copy("amazon_2024_valentines_best_sellers.csv")
# Out:
#                                                  title           brand  \
# 0    Ferrero Rocher, 24 Count, Premium Milk Chocola...  Ferrero Rocher
# 1    HERSHEY'S NUGGETS Assorted Chocolate, Valentin...       HERSHEY'S
# 2    LEGO Icons Flower Bouquet Building Decoration ...            LEGO
# 3    BodyRefresh Shower Steamers Aromatherapy - 8 P...     BodyRefresh
# 4    JoJowell Shower Steamers Aromatherapy - 21Pcs ...        JoJowell
# ..                                                 ...             ...
# 213  JOYIN 28 Packs Valentine's Day Gift Cards with...           JOYIN
# 214  THEMEROL Natural Gemstone Bracelet Gifts for D...        THEMEROL
# 215  Juegoal 28 Pack Valentines Day Gift Cards for ...         Juegoal
# 216  Double Couple Gift for Mom Women-Rose Cute Bea...   Double Couple
# 217  Valentine's Day Gifts For Her - Rose in Glass ...       Norcalway
#
#                                            description  starsBreakdown/3star  \
# ...

# %% [markdown]
# ### droping column that are not relevant (description, price  and price/currency)

# %%
df.drop("description", axis=1, inplace=True)
print(df)
# Out:
#                                                  title           brand  \
# 0    Ferrero Rocher, 24 Count, Premium Milk Chocola...  Ferrero Rocher
# 1    HERSHEY'S NUGGETS Assorted Chocolate, Valentin...       HERSHEY'S
# 2    LEGO Icons Flower Bouquet Building Decoration ...            LEGO
# 3    BodyRefresh Shower Steamers Aromatherapy - 8 P...     BodyRefresh
# 4    JoJowell Shower Steamers Aromatherapy - 21Pcs ...        JoJowell
# ..                                                 ...             ...
# 213  JOYIN 28 Packs Valentine's Day Gift Cards with...           JOYIN
# 214  THEMEROL Natural Gemstone Bracelet Gifts for D...        THEMEROL
# 215  Juegoal 28 Pack Valentines Day Gift Cards for ...         Juegoal
# 216  Double Couple Gift for Mom Women-Rose Cute Bea...   Double Couple
# 217  Valentine's Day Gifts For Her - Rose in Glass ...       Norcalway
#
#      starsBreakdown/3star  starsBreakdown/4star  starsBreakdown/5star  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 218 entries, 0 to 217
# Data columns (total 10 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   title                             218 non-null    object
#  1   brand                             217 non-null    object
#  2   starsBreakdown/3star              218 non-null    float64
#  3   starsBreakdown/4star              218 non-null    float64
#  4   starsBreakdown/5star              218 non-null    float64
#  5   reviewsCount                      216 non-null    float64
#  6   price                             0 non-null      float64
#  7   price/currency                    169 non-null    object
#  8   price/value                       169 non-null    float64
#  9   categoryPageData/productPosition  218 non-null    int64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 17.2+ KB

# %%
df.drop("price", axis=1, inplace=True)
print(df)
# Out:
#                                                  title           brand  \
# 0    Ferrero Rocher, 24 Count, Premium Milk Chocola...  Ferrero Rocher
# 1    HERSHEY'S NUGGETS Assorted Chocolate, Valentin...       HERSHEY'S
# 2    LEGO Icons Flower Bouquet Building Decoration ...            LEGO
# 3    BodyRefresh Shower Steamers Aromatherapy - 8 P...     BodyRefresh
# 4    JoJowell Shower Steamers Aromatherapy - 21Pcs ...        JoJowell
# ..                                                 ...             ...
# 213  JOYIN 28 Packs Valentine's Day Gift Cards with...           JOYIN
# 214  THEMEROL Natural Gemstone Bracelet Gifts for D...        THEMEROL
# 215  Juegoal 28 Pack Valentines Day Gift Cards for ...         Juegoal
# 216  Double Couple Gift for Mom Women-Rose Cute Bea...   Double Couple
# 217  Valentine's Day Gifts For Her - Rose in Glass ...       Norcalway
#
#      starsBreakdown/3star  starsBreakdown/4star  starsBreakdown/5star  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 218 entries, 0 to 217
# Data columns (total 9 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   title                             218 non-null    object
#  1   brand                             217 non-null    object
#  2   starsBreakdown/3star              218 non-null    float64
#  3   starsBreakdown/4star              218 non-null    float64
#  4   starsBreakdown/5star              218 non-null    float64
#  5   reviewsCount                      216 non-null    float64
#  6   price/currency                    169 non-null    object
#  7   price/value                       169 non-null    float64
#  8   categoryPageData/productPosition  218 non-null    int64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 15.5+ KB

# %%
df.drop("price/currency", axis=1, inplace=True)
print(df)
# Out:
#                                                  title           brand  \
# 0    Ferrero Rocher, 24 Count, Premium Milk Chocola...  Ferrero Rocher
# 1    HERSHEY'S NUGGETS Assorted Chocolate, Valentin...       HERSHEY'S
# 2    LEGO Icons Flower Bouquet Building Decoration ...            LEGO
# 3    BodyRefresh Shower Steamers Aromatherapy - 8 P...     BodyRefresh
# 4    JoJowell Shower Steamers Aromatherapy - 21Pcs ...        JoJowell
# ..                                                 ...             ...
# 213  JOYIN 28 Packs Valentine's Day Gift Cards with...           JOYIN
# 214  THEMEROL Natural Gemstone Bracelet Gifts for D...        THEMEROL
# 215  Juegoal 28 Pack Valentines Day Gift Cards for ...         Juegoal
# 216  Double Couple Gift for Mom Women-Rose Cute Bea...   Double Couple
# 217  Valentine's Day Gifts For Her - Rose in Glass ...       Norcalway
#
#      starsBreakdown/3star  starsBreakdown/4star  starsBreakdown/5star  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 218 entries, 0 to 217
# Data columns (total 8 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   title                             218 non-null    object
#  1   brand                             217 non-null    object
#  2   starsBreakdown/3star              218 non-null    float64
#  3   starsBreakdown/4star              218 non-null    float64
#  4   starsBreakdown/5star              218 non-null    float64
#  5   reviewsCount                      216 non-null    float64
#  6   price/value                       169 non-null    float64
#  7   categoryPageData/productPosition  218 non-null    int64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 13.8+ KB

# %% [markdown]
# ### checking missing values

# %%
df.isna()
# Out:
#      title  brand  starsBreakdown/3star  starsBreakdown/4star  \
# 0    False  False                 False                 False
# 1    False  False                 False                 False
# 2    False  False                 False                 False
# 3    False  False                 False                 False
# 4    False  False                 False                 False
# ..     ...    ...                   ...                   ...
# 213  False  False                 False                 False
# 214  False  False                 False                 False
# 215  False  False                 False                 False
# 216  False  False                 False                 False
# 217  False  False                 False                 False
#
#      starsBreakdown/5star  reviewsCount  price/value  \
# 0                   False         False        False
# 1                   False         False        False
# 2                   False         False        False
# ...

# %%
df.isna().sum()
# Out:
# title                                0
# brand                                1
# starsBreakdown/3star                 0
# starsBreakdown/4star                 0
# starsBreakdown/5star                 0
# reviewsCount                         2
# price/value                         49
# categoryPageData/productPosition     0
# dtype: int64

# %%
df.isna().sum()[['title','brand']]
# Out:
# title    0
# brand    1
# dtype: int64

# %%
df[['title', 'brand']].isna()
# Out:
#      title  brand
# 0    False  False
# 1    False  False
# 2    False  False
# 3    False  False
# 4    False  False
# ..     ...    ...
# 213  False  False
# 214  False  False
# 215  False  False
# 216  False  False
# 217  False  False
#
# [218 rows x 2 columns]

# %%
df[df['brand'].isna()]
# Out:
#                                                  title brand  \
# 211  Valentines Day Gifts: I Spy Valentine's Day Bo...   NaN
#
#      starsBreakdown/3star  starsBreakdown/4star  starsBreakdown/5star  \
# 211                   0.0                   0.0                   0.5
#
#      reviewsCount  price/value  categoryPageData/productPosition
# 211           2.0         7.98                               304

# %% [markdown]
# ### filling missing value for brand column

# %%
df['brand'].fillna(value='ISpy', inplace=True, limit=1, downcast='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 218 entries, 0 to 217
# Data columns (total 8 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   title                             218 non-null    object
#  1   brand                             218 non-null    object
#  2   starsBreakdown/3star              218 non-null    float64
#  3   starsBreakdown/4star              218 non-null    float64
#  4   starsBreakdown/5star              218 non-null    float64
#  5   reviewsCount                      216 non-null    float64
#  6   price/value                       169 non-null    float64
#  7   categoryPageData/productPosition  218 non-null    int64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 13.8+ KB

# %%
df.isna().sum()
# Out:
# title                                0
# brand                                0
# starsBreakdown/3star                 0
# starsBreakdown/4star                 0
# starsBreakdown/5star                 0
# reviewsCount                         2
# price/value                         49
# categoryPageData/productPosition     0
# dtype: int64

# %%
df.isna().sum()[['reviewsCount','price/value']]
# Out:
# reviewsCount     2
# price/value     49
# dtype: int64

# %%
df[['reviewsCount', 'price/value']].isna()
# Out:
#      reviewsCount  price/value
# 0           False        False
# 1           False        False
# 2           False        False
# 3           False        False
# 4           False        False
# ..            ...          ...
# 213         False        False
# 214         False         True
# 215         False        False
# 216         False        False
# 217         False        False
#
# [218 rows x 2 columns]

# %%
df[df['reviewsCount'].isna()]
# Out:
#                                                  title      brand  \
# 88   Confucia 32 Pack Valentine's Day Gifts Prefill...   Confucia
# 198  36 Pack Valentines Day Gifts for Kids Heart St...  fulasiteu
#
#      starsBreakdown/3star  starsBreakdown/4star  starsBreakdown/5star  \
# 88                    0.0                   0.0                   0.0
# 198                   0.0                   0.0                   0.0
#
#      reviewsCount  price/value  categoryPageData/productPosition
# 88            NaN        16.99                                55
# 198           NaN        11.99                               306

# %% [markdown]
# ### generating descriptive statistic of the dataframe

# %%
df.describe()
# Out:
#        starsBreakdown/3star  starsBreakdown/4star  starsBreakdown/5star  \
# count            218.000000            218.000000            218.000000
# mean               0.049220              0.105275              0.767936
# std                0.041966              0.066756              0.151997
# min                0.000000              0.000000              0.000000
# 25%                0.030000              0.072500              0.720000
# 50%                0.040000              0.100000              0.790000
# 75%                0.070000              0.130000              0.850000
# max                0.380000              0.490000              1.000000
#
#        reviewsCount  price/value  categoryPageData/productPosition
# count    216.000000   169.000000                        218.000000
# mean    2863.759259    18.046805                        127.123853
# std     7104.953282    11.696470                         91.812865
# ...

# %% [markdown]
# ### filling missing values for reviewsCount column using the generated mean on the statistic

# %%
df['reviewsCount'].fillna(value=2863.7, inplace=True, limit=2, downcast='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 218 entries, 0 to 217
# Data columns (total 8 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   title                             218 non-null    object
#  1   brand                             218 non-null    object
#  2   starsBreakdown/3star              218 non-null    float64
#  3   starsBreakdown/4star              218 non-null    float64
#  4   starsBreakdown/5star              218 non-null    float64
#  5   reviewsCount                      218 non-null    float64
#  6   price/value                       169 non-null    float64
#  7   categoryPageData/productPosition  218 non-null    int64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 13.8+ KB

# %% [markdown]
# ### viewing missing value rows for price/value column

# %%
df[df['price/value'].isna()]
# Out:
#                                                  title                  brand  \
# 16   I LOVE YOU Red Valentine Chocolate Dipped Oreo...  Olde Naples Chocolate
# 18   Ferrero Collection, 12 Count, Assorted Milk an...         Ferrero Rocher
# 20   Marycele Candle Warmer Lamp, Electric Candle L...               Marycele
# 24   SKITTLES Valentine's Day Wild Berry Chewy Cand...               Skittles
# 27   EGD Acrylic Personalized Gifts Spotify Plaque ...                    EGD
# 29   Burt's Bees Essential Everyday Beauty Valentin...            Burt's Bees
# 33   Candles Gifts for Her Funny Novelty Unique Val...                BFJLIFE
# 36   EBMORE Womens Fuzzy Socks Slipper Soft Cabin P...                 EBMORE
# 38   Valentine's Day Gift Care Package (50ct) Snack...               CRAVEBOX
# 39   LUCKOR Personalized Valentines Day Gifts for H...                 LUCKOR
# 41   LEGO Heart Ornament Building Toy Kit, Heart Sh...                   LEGO
# ...

# %% [markdown]
# ### filling missing value for price/value column using the generated mean on the statistic

# %%
df['price/value'].fillna(value=18.0, inplace=True, limit=49, downcast='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 218 entries, 0 to 217
# Data columns (total 8 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   title                             218 non-null    object
#  1   brand                             218 non-null    object
#  2   starsBreakdown/3star              218 non-null    float64
#  3   starsBreakdown/4star              218 non-null    float64
#  4   starsBreakdown/5star              218 non-null    float64
#  5   reviewsCount                      218 non-null    float64
#  6   price/value                       218 non-null    float64
#  7   categoryPageData/productPosition  218 non-null    int64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 13.8+ KB

# %% [markdown]
# ### confirming if there is still missing values

# %%
df.isna().sum()
# Out:
# title                               0
# brand                               0
# starsBreakdown/3star                0
# starsBreakdown/4star                0
# starsBreakdown/5star                0
# reviewsCount                        0
# price/value                         0
# categoryPageData/productPosition    0
# dtype: int64

# %%
df.shape
# Out:
# (218, 8)

# %% [markdown]
# ### Data Exploration Analysis

# %%
df.dtypes
# Out:
# title                                object
# brand                                object
# starsBreakdown/3star                float64
# starsBreakdown/4star                float64
# starsBreakdown/5star                float64
# reviewsCount                        float64
# price/value                         float64
# categoryPageData/productPosition      int64
# dtype: object

# %%
df['brand'].unique()
# Out:
# array(['Ferrero Rocher', "HERSHEY'S", 'LEGO', 'BodyRefresh', 'JoJowell',
#        'ChunRun', 'Body Restore', 'Tryuunion', 'JOYIN', 'Hallmark',
#        "Brach's", 'grace & stella', 'Olde Naples Chocolate',
#        'ORIENTAL CHERRY', 'Sophauteem', 'Marycele', 'Lindt', 'Starburst',
#        'ORALER', 'Skittles', 'BUNNY · JAMES ·', 'EGD',
#        'Philadelphia Candies', "Burt's Bees", 'LE CADEAU', 'QUNPON',
#        'STUNFASSOO', 'BFJLIFE', 'Likeny', 'EBMORE', 'CRAVEBOX', 'LUCKOR',
#        'Jinsome', 'Beferr', 'Push Pop', 'Peaceable Kingdom', 'ZALIK',
#        'Bazooka Candy Brands', "Pop n' Dulge", 'BAIMEI', 'Parima', 'Dove',
#        'MADDIFY', 'Genuvi', 'Nut Cravings', 'HeartspaceCards', 'Jetrvat',
#        'CHAIN & JO SWEETS', 'JO SWEETS', 'Otlonpe', 'iWenSheng',
#        'Butterfinger', 'AISunGoo', 'YAERZI', 'catnee', 'SWCANDY',
#        'GLAMOUR BOUTIQUE', 'Meiidoshine', 'VANLOVEMAC', 'SAPGIF',
#        'Childom', '100 GREETINGS', 'EUASOO', 'Feltom', 'Huameigf',
# ...

# %% [markdown]
# ### scatter plot showing the relationship between brand and price value

# %%
plt.figure(figsize=(12,30))
plt.scatter(df['price/value'], df['brand'])
plt.title('brand Vs.pricing in USD')
plt.ylabel('brand')
plt.xlabel('price/value')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(12,30))
plt.scatter(df['reviewsCount'], df['brand'])
plt.title('Brand VS Reviews')
plt.ylabel('reviewsCount')
plt.xlabel('brand')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.corr(numeric_only = True)
# Out:
#                                   starsBreakdown/3star  starsBreakdown/4star  \
# starsBreakdown/3star                          1.000000              0.154126
# starsBreakdown/4star                          0.154126              1.000000
# starsBreakdown/5star                         -0.260264             -0.310570
# reviewsCount                                 -0.052255             -0.020128
# price/value                                   0.050273             -0.020463
# categoryPageData/productPosition              0.082575              0.026374
#
#                                   starsBreakdown/5star  reviewsCount  \
# starsBreakdown/3star                         -0.260264     -0.052255
# starsBreakdown/4star                         -0.310570     -0.020128
# starsBreakdown/5star                          1.000000      0.095892
# reviewsCount                                  0.095892      1.000000
# price/value                                   0.057613      0.023827
# ...

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(numeric_only = True))
plt.title('Correlation Matrix')
plt.show()

# %%
sns.histplot(data=df, x='starsBreakdown/3star', kde=True)
# Out:
# <Axes: xlabel='starsBreakdown/3star', ylabel='Count'>

# %%
sns.displot(data=df, x='starsBreakdown/4star', kind='kde')
# Out:
# C:\Users\EDIRIN EUODIA KEYAMO\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df.head()
# Out:
#                                                title           brand  \
# 0  Ferrero Rocher, 24 Count, Premium Milk Chocola...  Ferrero Rocher
# 1  HERSHEY'S NUGGETS Assorted Chocolate, Valentin...       HERSHEY'S
# 2  LEGO Icons Flower Bouquet Building Decoration ...            LEGO
# 3  BodyRefresh Shower Steamers Aromatherapy - 8 P...     BodyRefresh
# 4  JoJowell Shower Steamers Aromatherapy - 21Pcs ...        JoJowell
#
#    starsBreakdown/3star  starsBreakdown/4star  starsBreakdown/5star  \
# 0                  0.02                  0.07                  0.89
# 1                  0.03                  0.10                  0.84
# 2                  0.01                  0.05                  0.92
# 3                  0.07                  0.15                  0.67
# 4                  0.10                  0.15                  0.63
#
#    reviewsCount  price/value  categoryPageData/productPosition
# 0       20021.0        11.39                                 7
# ...

# %%
sns.pairplot(df[['starsBreakdown/3star', 'starsBreakdown/4star', 'starsBreakdown/5star', 'price/value']], hue='price/value')
# Out:
# C:\Users\EDIRIN EUODIA KEYAMO\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### Top 10 brands using reviewsCount

# %%
top_10_brands = df.sort_values(by='reviewsCount', ascending=False).head(10)
print(top_10_brands)
# Out:
#                                                  title                 brand  \
# 54   BAIMEI Jade Roller & Gua Sha, Face Roller Redn...                BAIMEI
# 29   Burt's Bees Essential Everyday Beauty Valentin...           Burt's Bees
# 95   Ferrero Collection, 16 Count, Assorted Milk an...        Ferrero Rocher
# 12   Ferrero Rocher Collection, 48 Count, Gourmet A...        Ferrero Rocher
# 51   Valentine’s Candy Variety Pack 18 Count: Bulk ...  Bazooka Candy Brands
# 50   Burt's Bees Lip Balm Valentines Day Gifts, Pin...           Burt's Bees
# 165  HOME SMILE Ceramic Ring Dish Jewelry Tray for ...            HOME SMILE
# 15   grace & stella Under Eye Mask (Gold, 24 Pairs)...        grace & stella
# 0    Ferrero Rocher, 24 Count, Premium Milk Chocola...        Ferrero Rocher
# 53   Body Restore Shower Steamers Aromatherapy 15 P...          Body Restore
#
#      starsBreakdown/3star  starsBreakdown/4star  starsBreakdown/5star  \
# ...

# %%
plt.figure(figsize=(8, 6))
plt.bar(top_10_brands['brand'], top_10_brands['reviewsCount'], color='skyblue')
plt.xlabel('brand')
plt.ylabel('reviewsCount')
plt.title('Top 10 brand based on reviewsCount')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.show()

# %% [markdown]
# ### Model Building

# %%
import numpy as np
from sklearn import linear_model

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 218 entries, 0 to 217
# Data columns (total 8 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   title                             218 non-null    object
#  1   brand                             218 non-null    object
#  2   starsBreakdown/3star              218 non-null    float64
#  3   starsBreakdown/4star              218 non-null    float64
#  4   starsBreakdown/5star              218 non-null    float64
#  5   reviewsCount                      218 non-null    float64
#  6   price/value                       218 non-null    float64
#  7   categoryPageData/productPosition  218 non-null    int64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 13.8+ KB

# %% [markdown]
# ### Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression

# %%
#Create an instance of the linear reg model

model = LinearRegression()

# %% [markdown]
# ### changing string data to float

# %%
###Generate random float numbers for replacement
random_floats = np.random.rand(len(df))
df['brand'] = random_floats

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 218 entries, 0 to 217
# Data columns (total 8 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   title                             218 non-null    object
#  1   brand                             218 non-null    float64
#  2   starsBreakdown/3star              218 non-null    float64
#  3   starsBreakdown/4star              218 non-null    float64
#  4   starsBreakdown/5star              218 non-null    float64
#  5   reviewsCount                      218 non-null    float64
#  6   price/value                       218 non-null    float64
#  7   categoryPageData/productPosition  218 non-null    int64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 13.8+ KB

# %%
random_floats = np.random.rand(len(df))
df['title'] = random_floats

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 218 entries, 0 to 217
# Data columns (total 8 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   title                             218 non-null    float64
#  1   brand                             218 non-null    float64
#  2   starsBreakdown/3star              218 non-null    float64
#  3   starsBreakdown/4star              218 non-null    float64
#  4   starsBreakdown/5star              218 non-null    float64
#  5   reviewsCount                      218 non-null    float64
#  6   price/value                       218 non-null    float64
#  7   categoryPageData/productPosition  218 non-null    int64
# dtypes: float64(7), int64(1)
# memory usage: 13.8 KB

# %% [markdown]
# ### Training and Testing of Dataset using LINEAR REGRESSION MODEL

# %%
X = df[['brand', 'title', 'starsBreakdown/3star', 'starsBreakdown/4star', 'starsBreakdown/5star', 'categoryPageData/productPosition']]

# %%
y=df[['price/value', 'categoryPageData/productPosition']]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
X_train
# Out:
#         brand     title  starsBreakdown/3star  starsBreakdown/4star  \
# 43   0.433906  0.473120                  0.02                  0.06
# 80   0.125733  0.356205                  0.03                  0.07
# 9    0.417388  0.543562                  0.06                  0.13
# 170  0.827448  0.612435                  0.04                  0.06
# 36   0.929470  0.862247                  0.04                  0.10
# ..        ...       ...                   ...                   ...
# 63   0.482544  0.596265                  0.06                  0.09
# 70   0.280279  0.516247                  0.02                  0.07
# 81   0.493959  0.772247                  0.04                  0.09
# 11   0.878952  0.881127                  0.03                  0.10
# 95   0.820961  0.705930                  0.03                  0.09
#
#      starsBreakdown/5star  categoryPageData/productPosition
# 43                   0.89                                12
# ...

# %%
X_test
# Out:
#         brand     title  starsBreakdown/3star  starsBreakdown/4star  \
# 34   0.286218  0.390550                  0.06                  0.12
# 74   0.824642  0.533976                  0.00                  0.39
# 50   0.872215  0.453503                  0.03                  0.10
# 176  0.587912  0.973364                  0.05                  0.08
# 134  0.373355  0.329963                  0.00                  0.00
# ..        ...       ...                   ...                   ...
# 90   0.702071  0.270445                  0.04                  0.09
# 51   0.510178  0.168647                  0.03                  0.08
# 18   0.448403  0.795787                  0.04                  0.09
# 61   0.653602  0.296508                  0.02                  0.08
# 1    0.098397  0.467816                  0.03                  0.10
#
#      starsBreakdown/5star  categoryPageData/productPosition
# 34                   0.73                                29
# ...

# %%
y_train
# Out:
#      price/value  categoryPageData/productPosition
# 43         18.00                                12
# 80         16.95                                77
# 9          21.99                                52
# 170        16.95                               243
# 36         18.00                                28
# ..           ...                               ...
# 63         18.00                                91
# 70         14.97                                99
# 81         22.11                                73
# 11          9.99                                 5
# 95         18.00                                86
#
# [152 rows x 2 columns]

# %%
y_test
# Out:
#      price/value  categoryPageData/productPosition
# 34         11.99                                29
# 74         13.99                                70
# 50          9.79                                37
# 176        23.85                               226
# 134        19.99                                99
# ..           ...                               ...
# 90          6.99                                74
# 51         18.00                                54
# 18         18.00                                38
# 61         13.49                                92
# 1          10.69                                16
#
# [66 rows x 2 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
#Create an instance of the linear reg model

model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
X.columns
# Out:
# Index(['brand', 'title', 'starsBreakdown/3star', 'starsBreakdown/4star',
#        'starsBreakdown/5star', 'categoryPageData/productPosition'],
#       dtype='object')

# %%
model.coef_
# Out:
# array([[ 5.64114303e-01,  2.33999772e+00,  2.39603973e+01,
#          6.62986830e+00,  2.95479881e+00,  7.74476020e-03],
#        [-2.60017949e-15,  5.42171429e-14, -1.81778627e-13,
#          8.59340958e-15,  3.60745611e-14,  1.00000000e+00]])

# %%
model.intercept_
# Out:
# array([ 1.08255170e+01, -8.52651283e-14])

# %%
prediction = model.predict(X_test)

# %%
prediction
# Out:
# array([[ 16.51567168,  29.        ],
#        [ 17.4704218 ,  70.        ],
#        [ 16.55867701,  37.        ],
#        [ 19.21830326, 226.        ],
#        [ 15.52977447,  99.        ],
#        [ 16.08649752,  98.        ],
#        [ 18.57864659,  18.        ],
#        [ 16.01823159,  65.        ],
#        [ 18.09384951,  11.        ],
#        [ 18.39518206, 135.        ],
#        [ 17.9276595 , 102.        ],
#        [ 17.20955626,  87.        ],
#        [ 15.85200639,  78.        ],
#        [ 17.12865181, 123.        ],
#        [ 18.93540076, 310.        ],
#        [ 16.18465216,  13.        ],
#        [ 17.05986283, 114.        ],
#        [ 18.53721517, 124.        ],
#        [ 19.15652732, 146.        ],
#        [ 15.48720651, 111.        ],
#        [ 18.46997033, 227.        ],
#        [ 18.82683351,  79.        ],
#        [ 16.2814947 ,  23.        ],
#        [ 16.95455988, 191.        ],
#        [ 17.45390106,  49.        ],
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(y_test, prediction)
plt.ylabel('Predicted')
plt.xlabel('Actual values')
# Out:
# Text(0.5, 0, 'Actual values')

# %% [markdown]
# ### Model Evaluation using R-squared (R²)  metric

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import  r2_score
import numpy as np


# Evaluate the model using metrics
r2 = r2_score(y_test, y_pred)


print("R-squared (R2):", r2)
# Out:
# R-squared (R2): 0.484064236180364

# %% [markdown]
# ### The dataset was a sales trend on certain products that people purchase from Amazon on valentine's. It consisted of the brand name, the product position, price/value as well as the ratings of the products. We cleaned the data and build visuals from it.  After gaining insights from the visuals, we used this dataset to build a model that can predict the patterns of the sales in the long-term future, in order for the business to gain insights on what products are purchased the most and take required steps to ensure a consistent supply for the customers

# %% [markdown]
# ### Using linear regression we predicted our target (the product position as well as price/value) pattern for our products in the long run . The scatter plot indicated a constant increase in both values over the years to come. In order to test the reliability or efficiency of our model, we used the R-squared metric. According to Google, R-squared metric represents the proportion of the variance in the dependent variable that is explained by the independent variables in a regression model. It ranges from 0 to 1 , where 0 indicates that the model does not explain any variability in the dependent variable, and 1 indicates that the model perfectly explains the variability. And according to the results we concluded that our model was average (0.48) . It couldn't annotate the variability perfectly but it did give us insights to our data.
